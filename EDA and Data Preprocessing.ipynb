# %%
import pandas as pd

# Read in track metadata with genre labels
tracks = pd.read_csv('datasets/fma-rock-vs-hiphop.csv')

# Read in track metrics with the features
echonest_metrics = pd.read_json('datasets/echonest-metrics.json', precise_float=True)

# Merge the relevant columns of tracks and echonest_metrics
echo_tracks = echonest_metrics.merge(tracks[['genre_top', 'track_id']], on='track_id')

# Inspect the resultant dataframe
echo_tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4802 entries, 0 to 4801
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track_id          4802 non-null   int64
#  1   acousticness      4802 non-null   float64
#  2   danceability      4802 non-null   float64
#  3   energy            4802 non-null   float64
#  4   instrumentalness  4802 non-null   float64
#  5   liveness          4802 non-null   float64
#  6   speechiness       4802 non-null   float64
#  7   tempo             4802 non-null   float64
#  8   valence           4802 non-null   float64
#  9   genre_top         4802 non-null   object
# dtypes: float64(8), int64(1), object(1)
# memory usage: 412.7+ KB

# %%
# Create a correlation matrix
corr_metrics = echonest_metrics.corr()
corr_metrics.style.background_gradient()
# Out:
# <style  type="text/css" >
# #T_7577d_row0_col0,#T_7577d_row1_col1,#T_7577d_row2_col2,#T_7577d_row3_col3,#T_7577d_row4_col4,#T_7577d_row5_col5,#T_7577d_row6_col6,#T_7577d_row7_col7,#T_7577d_row8_col8{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_7577d_row0_col1{
#             background-color:  #eae6f1;
#             color:  #000000;
#         }#T_7577d_row0_col2{
#             background-color:  #d2d2e7;
#             color:  #000000;
#         }#T_7577d_row0_col3{
#             background-color:  #9ab8d8;
#             color:  #000000;
#         }#T_7577d_row0_col4,#T_7577d_row1_col0,#T_7577d_row1_col2,#T_7577d_row1_col3,#T_7577d_row1_col7,#T_7577d_row2_col5,#T_7577d_row3_col1,#T_7577d_row4_col0,#T_7577d_row4_col6,#T_7577d_row4_col8{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_7577d_row0_col5{
#             background-color:  #ede7f2;
#             color:  #000000;
#         }#T_7577d_row0_col6{
#             background-color:  #eee8f3;
#             color:  #000000;
#         }#T_7577d_row0_col7{
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }#T_7577d_row0_col8{
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }#T_7577d_row1_col4{
#             background-color:  #bdc8e1;
#             color:  #000000;
#         }#T_7577d_row1_col5,#T_7577d_row6_col0{
#             background-color:  #e4e1ef;
#             color:  #000000;
#         }#T_7577d_row1_col6,#T_7577d_row6_col8{
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }#T_7577d_row1_col8,#T_7577d_row6_col4{
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }#T_7577d_row2_col0{
#             background-color:  #c0c9e2;
#             color:  #000000;
#         }#T_7577d_row2_col1{
#             background-color:  #dddbec;
#             color:  #000000;
#         }#T_7577d_row2_col3,#T_7577d_row5_col3{
#             background-color:  #adc1dd;
#             color:  #000000;
#         }#T_7577d_row2_col4,#T_7577d_row6_col7{
#             background-color:  #ece7f2;
#             color:  #000000;
#         }#T_7577d_row2_col6,#T_7577d_row3_col8,#T_7577d_row6_col3{
#             background-color:  #b9c6e0;
#             color:  #000000;
#         }#T_7577d_row2_col7{
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }#T_7577d_row2_col8{
#             background-color:  #73a9cf;
#             color:  #000000;
#         }#T_7577d_row3_col0{
#             background-color:  #bbc7e0;
#             color:  #000000;
#         }#T_7577d_row3_col2{
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }#T_7577d_row3_col4{
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }#T_7577d_row3_col5{
#             background-color:  #e3e0ee;
#             color:  #000000;
#         }#T_7577d_row3_col6{
#             background-color:  #e2dfee;
#             color:  #000000;
#         }#T_7577d_row3_col7,#T_7577d_row6_col2{
#             background-color:  #bfc9e1;
#             color:  #000000;
#         }#T_7577d_row4_col1{
#             background-color:  #9ebad9;
#             color:  #000000;
#         }#T_7577d_row4_col2{
#             background-color:  #f6eff7;
#             color:  #000000;
#         }#T_7577d_row4_col3{
#             background-color:  #b8c6e0;
#             color:  #000000;
#         }#T_7577d_row4_col5{
#             background-color:  #f4eef6;
#             color:  #000000;
#         }#T_7577d_row4_col7,#T_7577d_row7_col5{
#             background-color:  #ede8f3;
#             color:  #000000;
#         }#T_7577d_row5_col0,#T_7577d_row8_col7{
#             background-color:  #d8d7e9;
#             color:  #000000;
#         }#T_7577d_row5_col1,#T_7577d_row6_col1{
#             background-color:  #afc1dd;
#             color:  #000000;
#         }#T_7577d_row5_col2{
#             background-color:  #faf2f8;
#             color:  #000000;
#         }#T_7577d_row5_col4{
#             background-color:  #e1dfed;
#             color:  #000000;
#         }#T_7577d_row5_col6,#T_7577d_row8_col0{
#             background-color:  #d3d4e7;
#             color:  #000000;
#         }#T_7577d_row5_col7{
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }#T_7577d_row5_col8,#T_7577d_row8_col5{
#             background-color:  #eee9f3;
#             color:  #000000;
#         }#T_7577d_row6_col5{
#             background-color:  #dedcec;
#             color:  #000000;
#         }#T_7577d_row7_col0{
#             background-color:  #d6d6e9;
#             color:  #000000;
#         }#T_7577d_row7_col1{
#             background-color:  #d1d2e6;
#             color:  #000000;
#         }#T_7577d_row7_col2{
#             background-color:  #f3edf5;
#             color:  #000000;
#         }#T_7577d_row7_col3{
#             background-color:  #7dacd1;
#             color:  #000000;
#         }#T_7577d_row7_col4,#T_7577d_row7_col8{
#             background-color:  #d2d3e7;
#             color:  #000000;
#         }#T_7577d_row7_col6{
#             background-color:  #dad9ea;
#             color:  #000000;
#         }#T_7577d_row8_col1{
#             background-color:  #cccfe5;
#             color:  #000000;
#         }#T_7577d_row8_col2{
#             background-color:  #69a5cc;
#             color:  #000000;
#         }#T_7577d_row8_col3{
#             background-color:  #80aed2;
#             color:  #000000;
#         }#T_7577d_row8_col4{
#             background-color:  #efe9f3;
#             color:  #000000;
#         }#T_7577d_row8_col6{
#             background-color:  #ced0e6;
#             color:  #000000;
#         }</style><table id="T_7577d_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >track_id</th>        <th class="col_heading level0 col1" >acousticness</th>        <th class="col_heading level0 col2" >danceability</th>        <th class="col_heading level0 col3" >energy</th>        <th class="col_heading level0 col4" >instrumentalness</th>        <th class="col_heading level0 col5" >liveness</th>        <th class="col_heading level0 col6" >speechiness</th>        <th class="col_heading level0 col7" >tempo</th>        <th class="col_heading level0 col8" >valence</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7577d_level0_row0" class="row_heading level0 row0" >track_id</th>
#                         <td id="T_7577d_row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_7577d_row0_col1" class="data row0 col1" >-0.279829</td>
#                         <td id="T_7577d_row0_col2" class="data row0 col2" >0.102056</td>
#                         <td id="T_7577d_row0_col3" class="data row0 col3" >0.121991</td>
#                         <td id="T_7577d_row0_col4" class="data row0 col4" >-0.283206</td>
#                         <td id="T_7577d_row0_col5" class="data row0 col5" >-0.004059</td>
#                         <td id="T_7577d_row0_col6" class="data row0 col6" >-0.075077</td>
#                         <td id="T_7577d_row0_col7" class="data row0 col7" >0.004313</td>
#                         <td id="T_7577d_row0_col8" class="data row0 col8" >0.020201</td>
#             </tr>
#             <tr>
#                         <th id="T_7577d_level0_row1" class="row_heading level0 row1" >acousticness</th>
#                         <td id="T_7577d_row1_col0" class="data row1 col0" >-0.279829</td>
#                         <td id="T_7577d_row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_7577d_row1_col2" class="data row1 col2" >-0.189599</td>
#                         <td id="T_7577d_row1_col3" class="data row1 col3" >-0.477273</td>
#                         <td id="T_7577d_row1_col4" class="data row1 col4" >0.110033</td>
#                         <td id="T_7577d_row1_col5" class="data row1 col5" >0.041319</td>
#                         <td id="T_7577d_row1_col6" class="data row1 col6" >0.038785</td>
#                         <td id="T_7577d_row1_col7" class="data row1 col7" >-0.110701</td>
#                         <td id="T_7577d_row1_col8" class="da

# %%
# Import train_test_split function and Decision tree classifier
from sklearn.model_selection import train_test_split

# Create features
features = echo_tracks.drop(["genre_top", "track_id"], axis=1).values

# Create labels
labels = echo_tracks["genre_top"].values

# Split our data
train_features, test_features, train_labels, test_labels = train_test_split(features, labels, 
                                                                            random_state=10)

# %%
# Import the StandardScaler
from sklearn.preprocessing import StandardScaler

# Scale train_features and set the values to a new variable
scaler = StandardScaler()

# Scale train_features and test_features
scaled_train_features = scaler.fit_transform(train_features)
scaled_test_features = scaler.transform(test_features)

# %%
# This is just to make plots appear in the notebook
# %matplotlib inline

# Import our plotting module, and PCA class
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Get our explained variance ratios from PCA using all features
pca = PCA()
pca.fit(scaled_train_features)
exp_variance = pca.explained_variance_ratio_

# plot the explained variance using a barplot
fig, ax = plt.subplots()
ax.bar(range(pca.n_components_), exp_variance)
ax.set_xlabel('Principal Component #')
# Out:
# Text(0.5, 0, 'Principal Component #')

# %%
import numpy as np

# Calculate the cumulative explained variance
cum_exp_variance = np.cumsum(exp_variance)

# Plot the cumulative explained variance and draw a dashed line at 0.85.
fig, ax = plt.subplots()
ax.plot(cum_exp_variance)
ax.axhline(y=0.85, linestyle='--')

# %%
# Perform PCA with the chosen number of components and project data onto components
pca = PCA(n_components=6, random_state=10)

# Fit and transform the scaled training features using pca
train_pca = pca.fit_transform(scaled_train_features)

# Fit and transform the scaled test features using pca
test_pca = pca.transform(scaled_test_features)
